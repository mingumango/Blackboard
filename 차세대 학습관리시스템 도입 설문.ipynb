# %%
import pandas as pd

# %%
df = pd.read_excel('블랙보드만족도조사_학생_데이터분석공모전.xlsx')
df
# Out:
#                         Timestamp    UniqID              소속    학년 성별  \
# 0     2022/10/18 1:45:14 PM GMT+9  C5559ekz    교육대학원 생물교육전공  석사과정  여
# 1    2022/10/24 10:11:29 AM GMT+9  S9340unw      정보대학 컴퓨터학과   1학년  여
# 2    2022/10/24 10:14:12 AM GMT+9  Q6348ilg       경영대학 경영학과   4학년  여
# 3    2022/10/24 10:23:01 AM GMT+9  F7696nak     문과대학 중어중문학과   3학년  여
# 4    2022/10/24 10:26:54 AM GMT+9  C5856rtq        이과대학 화학과   2학년  여
# ..                            ...       ...             ...   ... ..
# 215   2022/11/06 3:35:25 PM GMT+9  I1519dwz  정보보호대학 스마트보안학부   1학년  남
# 216   2022/11/06 3:55:13 PM GMT+9  N9471unp      정보대학 컴퓨터학과   2학년  여
# 217   2022/11/06 9:27:50 PM GMT+9  X229401j    이과대학 지구환경과학과   2학년  여
# 218  2022/11/06 10:58:07 PM GMT+9  K807327s    고려대학 반도체물리학과   4학년  남
# 219  2022/11/06 11:43:14 PM GMT+9  K4641ngi       심리대학 심리학부   1학년  남
#
#      1. 블랙보드 시스템에 전반적으로 만족하십니까? 2. 학기중 블랙보드에는 얼마나 자주 접속하십니까?  \
# 0                             4                    하루에 3회 이상
# ...

# %%
df46 = df.iloc[:,[50,51,52]]
df46
# Out:
#     46. 차세대 학습관리시스템(LMS)를 도입하는 것에 대해 어떻게 생각하십니까?   \
# 0                          차세대 학습관리시스템(LMS) 도입 희망
# 1                          차세대 학습관리시스템(LMS) 도입 희망
# 2                         현재 학습관리시스템(LMS) 블랙보드 유지
# 3                         현재 학습관리시스템(LMS) 블랙보드 유지
# 4                                            상관없음
# ..                                            ...
# 215                       현재 학습관리시스템(LMS) 블랙보드 유지
# 216                       현재 학습관리시스템(LMS) 블랙보드 유지
# 217                       현재 학습관리시스템(LMS) 블랙보드 유지
# 218                                          상관없음
# 219                                          상관없음
#
#     47. 차세대 학습관리시스템(LMS)을 도입을 희망하지 않는 이유에 대해 작성하여 주십시오.  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                            변경시 혼란 가중
# 3                                                현재 만족
# 4                                                  NaN
# ...

# %%
df46.columns
# Out:
# Index(['46. 차세대 학습관리시스템(LMS)를 도입하는 것에 대해 어떻게 생각하십니까? ',
#        '47. 차세대 학습관리시스템(LMS)을 도입을 희망하지 않는 이유에 대해 작성하여 주십시오.',
#        '48. 차세대 학습관리시스템(LMS)을 도입을 희망하는 이유에 대해 작성하여 주십시오.'],
#       dtype='object')

# %%
df46['46. 차세대 학습관리시스템(LMS)를 도입하는 것에 대해 어떻게 생각하십니까? '].unique()
# Out:
# array(['차세대 학습관리시스템(LMS) 도입 희망', '현재 학습관리시스템(LMS) 블랙보드 유지', '상관없음'],
#       dtype=object)

# %%
df_o = df46.loc[df['46. 차세대 학습관리시스템(LMS)를 도입하는 것에 대해 어떻게 생각하십니까? ']=='차세대 학습관리시스템(LMS) 도입 희망']
df_o
# Out:
#     46. 차세대 학습관리시스템(LMS)를 도입하는 것에 대해 어떻게 생각하십니까?   \
# 0                          차세대 학습관리시스템(LMS) 도입 희망
# 1                          차세대 학습관리시스템(LMS) 도입 희망
# 5                          차세대 학습관리시스템(LMS) 도입 희망
# 8                          차세대 학습관리시스템(LMS) 도입 희망
# 9                          차세대 학습관리시스템(LMS) 도입 희망
# 10                         차세대 학습관리시스템(LMS) 도입 희망
# 14                         차세대 학습관리시스템(LMS) 도입 희망
# 16                         차세대 학습관리시스템(LMS) 도입 희망
# 18                         차세대 학습관리시스템(LMS) 도입 희망
# 19                         차세대 학습관리시스템(LMS) 도입 희망
# 20                         차세대 학습관리시스템(LMS) 도입 희망
# 21                         차세대 학습관리시스템(LMS) 도입 희망
# 27                         차세대 학습관리시스템(LMS) 도입 희망
# 28                         차세대 학습관리시스템(LMS) 도입 희망
# 33                         차세대 학습관리시스템(LMS) 도입 희망
# 34                         차세대 학습관리시스템(LMS) 도입 희망
# 38                         차세대 학습관리시스템(LMS) 도입 희망
# 45                         차세대 학습관리시스템(LMS) 도입 희망
# ...

# %%
df_o['47. 차세대 학습관리시스템(LMS)을 도입을 희망하지 않는 이유에 대해 작성하여 주십시오.']
# 희망을 한 사람 중 희망 하지 않는 이유를 쓴 사람은 없다.
# 지워도 됨
# Out:
# 0      NaN
# 1      NaN
# 5      NaN
# 8      NaN
# 9      NaN
# 10     NaN
# 14     NaN
# 16     NaN
# 18     NaN
# 19     NaN
# 20     NaN
# 21     NaN
# 27     NaN
# 28     NaN
# 33     NaN
# 34     NaN
# 38     NaN
# 45     NaN
# 46     NaN
# 51     NaN
# 55     NaN
# 56     NaN
# 62     NaN
# 65     NaN
# 76     NaN
# 79     NaN
# 83     NaN
# 86     NaN
# 87     NaN
# 88     NaN
# 89     NaN
# 95     NaN
# 103    NaN
# 105    NaN
# 107    NaN
# 109    NaN
# 111    NaN
# 112    NaN
# 121    NaN
# 123    NaN
# 125    NaN
# 126    NaN
# 127    NaN
# 130    NaN
# 132    NaN
# 133    NaN
# 138    NaN
# 147    NaN
# 150    NaN
# 153    NaN
# 154    NaN
# 157    NaN
# 158    NaN
# 171    NaN
# 172    NaN
# 179    NaN
# 188    NaN
# 205    NaN
# 209    NaN
# Name: 47. 차세대 학습관리시스템(LMS)을 도입을 희망하지 않는 이유에 대해 작성하여 주십시오., dtype: object

# %%
df_o.drop(y,axis=1, inplace=True)
df_o
# Out:
# C:\Users\Mingyoo Son\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#     46. 차세대 학습관리시스템(LMS)를 도입하는 것에 대해 어떻게 생각하십니까?   \
# 0                          차세대 학습관리시스템(LMS) 도입 희망
# 1                          차세대 학습관리시스템(LMS) 도입 희망
# 5                          차세대 학습관리시스템(LMS) 도입 희망
# 8                          차세대 학습관리시스템(LMS) 도입 희망
# 9                          차세대 학습관리시스템(LMS) 도입 희망
# 10                         차세대 학습관리시스템(LMS) 도입 희망
# 14                         차세대 학습관리시스템(LMS) 도입 희망
# 16                         차세대 학습관리시스템(LMS) 도입 희망
# 18                         차세대 학습관리시스템(LMS) 도입 희망
# 19                         차세대 학습관리시스템(LMS) 도입 희망
# 20                         차세대 학습관리시스템(LMS) 도입 희망
# ...

# %%
df_o.isnull().count()
# Out:
# 46. 차세대 학습관리시스템(LMS)를 도입하는 것에 대해 어떻게 생각하십니까?        59
# 48. 차세대 학습관리시스템(LMS)을 도입을 희망하는 이유에 대해 작성하여 주십시오.    59
# dtype: int64

# %%
df_o.dropna(inplace=True)
df_o
# Out:
# C:\Users\Mingyoo Son\anaconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#     46. 차세대 학습관리시스템(LMS)를 도입하는 것에 대해 어떻게 생각하십니까?   \
# 0                          차세대 학습관리시스템(LMS) 도입 희망
# 1                          차세대 학습관리시스템(LMS) 도입 희망
# 5                          차세대 학습관리시스템(LMS) 도입 희망
# 16                         차세대 학습관리시스템(LMS) 도입 희망
# 18                         차세대 학습관리시스템(LMS) 도입 희망
# 20                         차세대 학습관리시스템(LMS) 도입 희망
# 21                         차세대 학습관리시스템(LMS) 도입 희망
# 28                         차세대 학습관리시스템(LMS) 도입 희망
# 33                         차세대 학습관리시스템(LMS) 도입 희망
# 34                         차세대 학습관리시스템(LMS) 도입 희망
# 38                         차세대 학습관리시스템(LMS) 도입 희망
# ...

# %%
df_x = df46.loc[df['46. 차세대 학습관리시스템(LMS)를 도입하는 것에 대해 어떻게 생각하십니까? ']=='현재 학습관리시스템(LMS) 블랙보드 유지']
df_x
# Out:
#     46. 차세대 학습관리시스템(LMS)를 도입하는 것에 대해 어떻게 생각하십니까?   \
# 2                         현재 학습관리시스템(LMS) 블랙보드 유지
# 3                         현재 학습관리시스템(LMS) 블랙보드 유지
# 6                         현재 학습관리시스템(LMS) 블랙보드 유지
# 12                        현재 학습관리시스템(LMS) 블랙보드 유지
# 15                        현재 학습관리시스템(LMS) 블랙보드 유지
# ..                                            ...
# 210                       현재 학습관리시스템(LMS) 블랙보드 유지
# 211                       현재 학습관리시스템(LMS) 블랙보드 유지
# 215                       현재 학습관리시스템(LMS) 블랙보드 유지
# 216                       현재 학습관리시스템(LMS) 블랙보드 유지
# 217                       현재 학습관리시스템(LMS) 블랙보드 유지
#
#     47. 차세대 학습관리시스템(LMS)을 도입을 희망하지 않는 이유에 대해 작성하여 주십시오.  \
# 2                                            변경시 혼란 가중
# 3                                                현재 만족
# 6                                                  NaN
# 12                                          시스템 불안정 우려
# 15                 새 시스템 도입에 따른 효익이 불확실하고 새로 적응하기가 불편함
# ...

# %%
x,y,z = df46.columns

# %%
df_x[z].isnull().sum()
# 현재 블랙보드 유지하는 사람 중 도입 희망을 작성한 사람 없음
# 지워도 됨.
# Out:
# 99

# %%
df_x.drop(z,axis=1,inplace=True)
df_x
# Out:
# C:\Users\Mingyoo Son\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#     46. 차세대 학습관리시스템(LMS)를 도입하는 것에 대해 어떻게 생각하십니까?   \
# 2                         현재 학습관리시스템(LMS) 블랙보드 유지
# 3                         현재 학습관리시스템(LMS) 블랙보드 유지
# 6                         현재 학습관리시스템(LMS) 블랙보드 유지
# 12                        현재 학습관리시스템(LMS) 블랙보드 유지
# 15                        현재 학습관리시스템(LMS) 블랙보드 유지
# ..                                            ...
# 210                       현재 학습관리시스템(LMS) 블랙보드 유지
# 211                       현재 학습관리시스템(LMS) 블랙보드 유지
# 215                       현재 학습관리시스템(LMS) 블랙보드 유지
# 216                       현재 학습관리시스템(LMS) 블랙보드 유지
# 217                       현재 학습관리시스템(LMS) 블랙보드 유지
#
# ...

# %%
df_x
# Out:
#     46. 차세대 학습관리시스템(LMS)를 도입하는 것에 대해 어떻게 생각하십니까?   \
# 2                         현재 학습관리시스템(LMS) 블랙보드 유지
# 3                         현재 학습관리시스템(LMS) 블랙보드 유지
# 6                         현재 학습관리시스템(LMS) 블랙보드 유지
# 12                        현재 학습관리시스템(LMS) 블랙보드 유지
# 15                        현재 학습관리시스템(LMS) 블랙보드 유지
# ..                                            ...
# 210                       현재 학습관리시스템(LMS) 블랙보드 유지
# 211                       현재 학습관리시스템(LMS) 블랙보드 유지
# 215                       현재 학습관리시스템(LMS) 블랙보드 유지
# 216                       현재 학습관리시스템(LMS) 블랙보드 유지
# 217                       현재 학습관리시스템(LMS) 블랙보드 유지
#
#     47. 차세대 학습관리시스템(LMS)을 도입을 희망하지 않는 이유에 대해 작성하여 주십시오.
# 2                                            변경시 혼란 가중
# 3                                                현재 만족
# 6                                                  NaN
# 12                                          시스템 불안정 우려
# 15                 새 시스템 도입에 따른 효익이 불확실하고 새로 적응하기가 불편함
# ...

# %%
df_x.isnull().sum()
# Out:
# 46. 차세대 학습관리시스템(LMS)를 도입하는 것에 대해 어떻게 생각하십니까?            0
# 47. 차세대 학습관리시스템(LMS)을 도입을 희망하지 않는 이유에 대해 작성하여 주십시오.    25
# dtype: int64

# %%
df_x.dropna(inplace=True)
df_x
# Out:
# C:\Users\Mingyoo Son\anaconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#     46. 차세대 학습관리시스템(LMS)를 도입하는 것에 대해 어떻게 생각하십니까?   \
# 2                         현재 학습관리시스템(LMS) 블랙보드 유지
# 3                         현재 학습관리시스템(LMS) 블랙보드 유지
# 12                        현재 학습관리시스템(LMS) 블랙보드 유지
# 15                        현재 학습관리시스템(LMS) 블랙보드 유지
# 17                        현재 학습관리시스템(LMS) 블랙보드 유지
# ..                                            ...
# 208                       현재 학습관리시스템(LMS) 블랙보드 유지
# 211                       현재 학습관리시스템(LMS) 블랙보드 유지
# 215                       현재 학습관리시스템(LMS) 블랙보드 유지
# 216                       현재 학습관리시스템(LMS) 블랙보드 유지
# 217                       현재 학습관리시스템(LMS) 블랙보드 유지
#
# ...

# %%
df_n = df46.loc[df46[x]=='상관없음']
df_n
# Out:
#     46. 차세대 학습관리시스템(LMS)를 도입하는 것에 대해 어떻게 생각하십니까?   \
# 4                                            상관없음
# 7                                            상관없음
# 11                                           상관없음
# 13                                           상관없음
# 24                                           상관없음
# ..                                            ...
# 212                                          상관없음
# 213                                          상관없음
# 214                                          상관없음
# 218                                          상관없음
# 219                                          상관없음
#
#     47. 차세대 학습관리시스템(LMS)을 도입을 희망하지 않는 이유에 대해 작성하여 주십시오.  \
# 4                                                  NaN
# 7                                                  NaN
# 11                                                 NaN
# 13                                                 NaN
# 24                                                 NaN
# ...

# %%
df_n.isnull().sum()
# 상관 없다고 한 사람은 전원 47, 48에 답을 하지 않았다.
# 무시해도 됨.
# Out:
# 46. 차세대 학습관리시스템(LMS)를 도입하는 것에 대해 어떻게 생각하십니까?            0
# 47. 차세대 학습관리시스템(LMS)을 도입을 희망하지 않는 이유에 대해 작성하여 주십시오.    62
# 48. 차세대 학습관리시스템(LMS)을 도입을 희망하는 이유에 대해 작성하여 주십시오.       62
# dtype: int64

# %% [markdown]
# ### 결과
# - 가장 중점적으로 분석할 것은 df_o이다.
# - 왜 새로운 lms를 도입하는 것이 좋은지 서술해준다.
# - df_o를 따로 엑셀로 정리해서 하나하나 읽어보는 것이 좋을 듯 하다.
# - df_x같은 경우도 읽어서 흐름을 파악하면 좋을 듯 하다.

# %%
# df_o 저장
import openpyxl
df_o.to_excel(r'C:\Users\Mingyoo Son\블랙보드 공모전\df_o.xlsx')

# %%
# df_x 저장
df_x.to_excel(r'C:\Users\Mingyoo Son\블랙보드 공모전\df_x.xlsx')
